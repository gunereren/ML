# %%
from warnings import filterwarnings
filterwarnings('ignore')
import numpy as np
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
import scipy as sp
from sklearn.cluster import KMeans

# %%
iris = sns.load_dataset("iris")
df = iris.copy()
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
sns.boxplot(data=df)
# Out:
# <Axes: >

# %%
sns.boxplot(df["sepal_width"]);

# %%
sns.pairplot(df)

# %%
bagimsiz = df.drop(columns=["species"]).columns
bagimsiz
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width'], dtype='object')

# %%
for col in bagimsiz:
    if col != "petal_width":
        plt.figure(figsize=(6, 6))
        sns.scatterplot(x= "petal_width", y=col, hue="species", data=df);

# %% [markdown]
# ## K-MEANS Model ve Görselleştirme

# %%
from sklearn.cluster import KMeans

# %%
kmeans = KMeans(n_clusters=3)
kmeans
# Out:
# KMeans(n_clusters=3)

# %%
k_fit = kmeans.fit(df.drop(columns=["species"]))

# %%
k_fit.n_clusters
# Out:
# 3

# %%
kumeler = k_fit.labels_

# %%
plt.scatter(x = df["petal_width"], y = df["sepal_width"], c= kumeler, s = 25, cmap="viridis")

plt.figure(figsize=(6, 6))
sns.scatterplot(x= "petal_width", y="sepal_width", hue="species", data=df);

# %%
df["kume_no"] = kumeler
df.iloc[45:55]
# Out:
#     sepal_length  sepal_width  petal_length  petal_width     species  kume_no
# 45           4.8          3.0           1.4          0.3      setosa        1
# 46           5.1          3.8           1.6          0.2      setosa        1
# 47           4.6          3.2           1.4          0.2      setosa        1
# 48           5.3          3.7           1.5          0.2      setosa        1
# 49           5.0          3.3           1.4          0.2      setosa        1
# 50           7.0          3.2           4.7          1.4  versicolor        2
# 51           6.4          3.2           4.5          1.5  versicolor        0
# 52           6.9          3.1           4.9          1.5  versicolor        2
# 53           5.5          2.3           4.0          1.3  versicolor        0
# 54           6.5          2.8           4.6          1.5  versicolor        0
